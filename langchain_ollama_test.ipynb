# %% [markdown]
# <a href="https://colab.research.google.com/github/uppercaveman/langchain-learn-test/blob/main/langchain_ollama_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 检查Python环境

# %%
# !pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !pip3 --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# # 安装LangChain

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.5/810.5 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.6/274.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.8/144.8 kB 17.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # 引入 OpenAI Key

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %% [markdown]
# # 提问 openai

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()
llm.invoke("请介绍一下李白")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-40-af870fc6a903> in <cell line: 4>()
#       2
#       3 llm = ChatOpenAI()
# ----> 4 llm.invoke("请介绍一下李白")
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     152         return cast(
#     153             ChatGeneration,
# --> 154             self.generate_prompt(
#     155                 [self._convert_input(input)],
#     156                 stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     548     ) -> LLMResult:
#     549         prompt_messages = [p.to_messages() for p in prompts]
# --> 550         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     551
# ...

# %% [markdown]
# 免费的Key到期了,报如上错误

# %% [markdown]
# # 安装ollama

# %%
# 下载ollama
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# 检查ollama安装情况
# !ollama -h
# Out:
# Large language model runner
#
# Usage:
#   ollama [flags]
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   show        Show information for a model
#   run         Run a model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
#
# Flags:
#   -h, --help      help for ollama
#   -v, --version   Show version information
#
# Use "ollama [command] --help" for more information about a command.

# %%
# !which ollama
# Out:
# /usr/local/bin/ollama

# %%
# !sudo chmod +x /usr/local/bin/ollama

# %% [markdown]
# # 启动ollama

# %%
# 后台启动
# !ollama serve > log.log 2>&1 &

# %% [markdown]
# # 下载ollama2模型

# %%
# !ollama pull llama2
# Out:
# pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# pulling 8934d96d3f08...   0% ▕▏    0 B/3.8 GB                  pulling manifest
# ...

# %% [markdown]
# # 提问 llama2

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama2")
llm.invoke("请介绍一下白居易")
# Out:
# '\n白居易 (701-759 CE) was a prominent Chinese poet, writer, and statesman of the Tang Dynasty. He is considered one of the greatest poets in Chinese literature and is known for his works that capture the beauty and simplicity of everyday life.\n\nHere are some key facts about white居易:\n\n1. Name: White居易 (Bái Jīn 白進)\n2. Life: Born in 701 CE in present-day Shaanxi Province, China. Died in 759 CE.\n3. Career: Served as a government official and advisor to several emperors during the Tang Dynasty.\n4. Works: Known for his poetry collection "Jintishi" (品集), which consists of 240 poems. His works are characterized by their concise language, vivid imagery, and simple yet profound themes.\n5. Style: White居易\'s style is known for its simplicity and clarity. He often used short sentences and phrases to convey complex ideas and emotions.\n6. Themes: His poems often focus on nature, the seasons, and the passage of time. He also wrote about politics, social issues, and personal relationships.\n7.
# ...

# %%
llm.invoke("说中文")
# Out:
# '你好！我是一个名叫LLaMA的AI语言模型。如果你有任何问题或需要帮助，请随时验脚推给我。我可以 помочь你解释中文、翻译中文或者帮助你学习中文。好吧！'

# %%
llm.invoke("请介绍一下白居易")
# Out:
# '\n白居易（772年-841年），字子長，號靜斋，安徽省歷史人物，唐代著名文学家、思想家、政治家。他是中国古典诗歌《白居易诗》的作者，也是中国古代著名的文化人物之一。\n\n生平：\n\n* 白居易出生於唐代安徽省宣恩縣（今属安徽省），家庭低微，父母在小麦种植时因为灌溉不当而离世。\n* 白居易幼年時被監獄負債，後來通過獨學和評審的成就，在唐代中期成為一位文学家和思想家。\n* 白居易於810年出任洛陽刑部尚書，但因為政治立場不同而辭職。\n* 白居易在唐代晚期被指定為“文人”，這也是他在文學界的最高地位。\n\n文学成就：\n\n* 白居易著有《白居易诗》等詩集，共計30多卷，是中国古典诗歌的代表作之一。其诗歌风格自由、浪漫、独特，具有辉照人生、思考世界的意境和感悟。\n* 白居易在文學界的成就是他詩歌的出色，他的诗歌不仅表达了自己的思想和感情，还反映了当时社会和政治环境。\n\n思想成就：\n\n* 白居易在思想方面的成就是他对古代中国文化和社会的深入释读和分析，他提出了“人性本善”的觀點，強调了人类的正能量和自由的要求。\n* 白居易认为，人类的本能是善的，但在 societal环境中会被障碍和腐化，因此需要 constants vigilance and self-cultivation。\n* 白居易的思想影响了后来的文化人物和社会发展，他的觀點在中国古代文化和现代社會仍有广泛的應用和研究。\n\n總結：\n\n白居易是唐代著名的文学家、思想家和政治家，他的诗歌和思想具有深刻的情感和智慧。他对古代中国文化和社会的深入释读和分析，提出了“人性本善”的觀點，强调了人类的正能量和自由的要求。白居易的思想和文学成就在中国古代和现代文化仍然具有广泛的應用和研究。'

# %%
llm.invoke("李白的一首诗,描述的是思乡之情,叫什么")
# Out:
# '\n李白的一首诗，描述的是思乡之情，叫“静夜思”。'

# %%
llm.invoke("静夜思全文")
# Out:
# "靜夜思（Jìng yè sī) is a famous Chinese poem written by the poet Bái Jiàng (Bái Jīng, 白峰) during the Tang Dynasty. Here is the full text of the poem:\n\n靜夜思\n\n树上有名花开，\n moon in the sky has not yet risen;\n the breeze blows, and the branches sway,\n a lonely sound, no one knows why.\n\n人在床上與梦同伴，\n dreams are like clouds that cannot be caught;\n in the morning light, they vanish away,\n leaving only emptiness and gray.\n\n风雨同时吟唱，\n the melody is sweet and pure;\n but when the dawn breaks, it ends too soon,\n leaving me with nothing but blue.\n\n离别的悲凉泪，\n tears fall like rain from my eyes;\n in this lonely night, I cannot help but think,\n of the one who is now far away.\n\nThe poem is a beautiful expression of longing and loneliness, as the poet reflects on the passing of time and the loss of love. The imagery is rich and evocative, with the branches swaying in the breeze, the moon rising in the sky, and the tears falling like rain from the poet's eyes. The poem is often interpreted as a
# ...

# %%
llm.invoke("莫等闲,白了少年头,出自哪首诗,作者是谁")
# 胡编乱造
# Out:
# '\n诗句 "莫等闲，白了少年头" comes from the poem "风雨同舟" (The Same Boat) by 唐朝 (Tang Dynasty) poet 李白 (Li Bai). The full quote is:\n\n「莫等闲，白了少年头。风雨同舟，游流同谐。」\n\nTranslation:\n\n"Don\'t be idle, and don\'t let your hair turn white. The wind and rain are the same, and the flowing water is in harmony."\n\nIn this poem, 李白 is using the image of a boat navigating through rough waters to describe the passage of time and the interconnectedness of all things. The phrase "莫等闲" (don\'t be idle) suggests that one should make the most of their time and not waste it, while "白了少年头" (and don\'t let your hair turn white) is a metaphor for aging and the passage of time. The poem encourages the reader to embrace the natural flow of life and to find beauty in the changing seasons and circumstances.'

# %%
llm.invoke("langsmith如何在测试方面提供帮助?")
# Out:
# "\n Langsmith can provide assistance in various ways during testing:\n\n1. Language Translation: Langsmith can translate test cases, test scripts, and test reports from one language to another, helping you to bridge the language gap and ensure consistency across different regions and cultures.\n2. Automated Testing: Langsmith can assist in automating tests using various testing frameworks and tools, such as Selenium, Appium, and JMeter. This can help reduce manual testing efforts and increase test coverage.\n3. Test Data Management: Langsmith can help manage and maintain test data, including creating test data sets, populating test databases, and ensuring data consistency across different environments.\n4. Test Environment Management: Langsmith can assist in setting up and managing test environments, including virtual machines, emulators, and simulators. This can help ensure that tests are executed in a consistent and controlled environment.\n5. Defect Reporting: Langsmith can help c
# ...

# %%
llm.invoke("使用Mojo怎么做人工智能开发?")
# Out:
# '\nMojo是一个Python库，用于执行人工智能任务。它提供了一个简单的API，可以轻松地使用机器学习算法和深度学习模型来解决多种问题。下面是使用Mojo怎么进行人工智能开发的基本步骤：\n\n1. 安装Mojo库：可以使用pip命令进行安装，例如：\n```\npip install mojo\n```\n2. 导入Mojo模块：在Python代码中导入Mojo模块，例如：\n```python\nfrom mojo import *\n```\n3. 选择算法：Mojo提供了多种机器学习算法和深度学习模型，可以根据需要选择合适的算法。例如，要使用linear regression算法，可以使用 following code：\n```python\nfrom sklearn.linear_model import LinearRegression\nreg = LinearRegression()\n```\n4. 数据preprocessing：在进行机器学习任务时，通常需要对数据进行预处理，例如去噪、扩展等。Mojo提供了一些预处理方法，可以使用following code：\n```python\nfrom mojo.preprocessing import *\n```\n5. 训练模型：将数据和算法参数组合起来，进行训练。例如，要训练一个linear regression模型，可以使用 following code：\n```python\nfrom sklearn.linear_model import LinearRegression\nX = ... # 输入数据\ny = ... # 目标数据\nreg = LinearRegression()\nreg.fit(X, y)\n```\n6. 评估模型： после训练模型，需要评估其性能。Mojo提供了多种评估方法，例如confusion matrix、accuracy等。例如，要计算模型的准确率，可以使用 following code：\n```python\nfrom sklearn.metrics import accuracy_score\ny_pred = reg.predict(X)\naccuracy = accuracy_score(y, y_pred)\nprint(
# ...

# %% [markdown]
# # 使用提示模版

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "你是世界一流的技术文档作家。"),
    ("user", "Mojo 是一种专为编写人工智能软件设计的编程语言，去年 8 月份正式发布，迄今为止已经积累了超过 17.5 万名开发者和 5 万个组织。人工智能模型通常使用多种编程语言编写。开发者会用 Python 实现神经网络最简单的部分，这种语言易于学习，但运行速度相对较慢。其余部分的代码通常使用 C++ 编写，C++ 的运行速度比 Python 更快，但学习难度也更大。")
])

# %%
# 组合一个简单Chain
chain = prompt | llm

# %%
chain.invoke({"input": "使用Mojo怎么做人工智能开发?"})
# llama学习到提示的内容,开始胡编了
# Out:
# 'As a world-renowned technical documentarian, I must say that Mojo is an innovative programming language specifically designed for writing artificial intelligence software. Released in August last year, it has already garnered over 17.5 million developers and 5 million organizations worldwide. Artificial intelligence models typically use a combination of programming languages to write their code. Developers often use Python for the simplest part of the neural network, as it is easy to learn but has relatively slow runtime. The remaining code is usually written in C++ for its faster execution speed, but with a higher learning curve.'

# %% [markdown]
# # 增加输出解释器

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser

# %%
chain.invoke({"input": "使用Mojo怎么做人工智能开发?"})
# 加不加好像没有什么作用?
# Out:
# '\nAs a world-class technical documentarian, I must say that Mojo is an innovative programming language specifically designed for writing artificial intelligence software. It was officially released in August last year and has since accumulated over 17.5 million developers and 5000 organizations. Artificial intelligence models typically use a combination of programming languages to write different parts of the code. Developers often use Python for the simplest part of the neural network, which is easy to learn but has relatively slow execution speed. The remaining code is usually written in C++ , which offers faster execution speeds than Python but requires more effort to learn.'
